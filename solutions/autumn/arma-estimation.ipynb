# %% [markdown]
# ## ARMA Modeling: Estimation
#
# **Functions**
#
# `tsa.SARIMAX`

# %%
import pandas as pd

data = pd.read_hdf("data/term-premium.h5","term_premium")
term = data.TERM

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
plt.rc("figure", figsize=(16,6))
sns.set_style("darkgrid")

term.plot.line()

# %% [markdown]
# ### Exercise 41
# Estimate an AR(1) on the term premium, and compute standard errors for the parameters.

# %%
import statsmodels.tsa.api as tsa

mod = tsa.SARIMAX(term, order=(1,0,0), trend='c')
res = mod.fit()
res.params
# Out:
# intercept    0.026812
# ar.L1        0.970925
# sigma2       0.065184
# dtype: float64

# %%
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Statespace Model Results
# ==============================================================================
# Dep. Variable:                   TERM   No. Observations:                  801
# Model:               SARIMAX(1, 0, 0)   Log Likelihood                 -44.433
# Date:                Fri, 24 Jan 2020   AIC                             94.865
# Time:                        19:08:24   BIC                            108.923
# Sample:                    04-01-1953   HQIC                           100.265
#                          - 12-01-2019
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0268      0.009      2.900      0.004       0.009       0.045
# ar.L1          0.9709      0.006    152.443      0.000       0.958       0.983
# sigma2         0.0652      0.001     57.298      0.000       0.063       0.067
# ===================================================================================
# Ljung-Box (Q):                      174.64   Jarque-Bera (JB):              9709.88
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.78   Skew:                             0.92
# Prob(H) (two-sided):                  0.04   Kurtosis:                        19.96
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ### Exercise 42
# Estimate an MA(5) on the term premium, and compute standard errors for the parameters.

# %%
mod = tsa.SARIMAX(term, order=(0,0,5), trend='c')
res = mod.fit()
res.params
# Out:
# C:\Anaconda\envs\anaconda-core\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:961: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# intercept    0.963706
# ma.L1        1.517253
# ma.L2        1.431168
# ma.L3        1.191622
# ma.L4        0.749124
# ma.L5        0.294956
# sigma2       0.084147
# dtype: float64

# %%
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Statespace Model Results
# ==============================================================================
# Dep. Variable:                   TERM   No. Observations:                  801
# Model:               SARIMAX(0, 0, 5)   Log Likelihood                -146.645
# Date:                Fri, 24 Jan 2020   AIC                            307.290
# Time:                        19:08:25   BIC                            340.091
# Sample:                    04-01-1953   HQIC                           319.890
#                          - 12-01-2019
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.9637      0.066     14.617      0.000       0.834       1.093
# ma.L1          1.5173      0.016     93.733      0.000       1.486       1.549
# ma.L2          1.4312      0.030     48.429      0.000       1.373       1.489
# ma.L3          1.1916      0.036     33.180      0.000       1.121       1.262
# ma.L4          0.7491      0.036     21.079      0.000       0.679       0.819
# ma.L5          0.2950      0.024     12.093      0.000       0.247       0.343
# sigma2         0.0841      0.003     31.215      0.000       0.079       0.089
# ===================================================================================
# Ljung-Box (Q):                      954.10   Jarque-Bera (JB):               659.40
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.07   Skew:                            -0.33
# Prob(H) (two-sided):                  0.59   Kurtosis:                         7.40
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ### Exercise 43
# Estimate an ARMA(1,1) on the term premium, and compute standard errors for the parameters.

# %%
mod = tsa.SARIMAX(term, order=(1,0,1), trend='c')
res = mod.fit()
res.params
# Out:
# intercept    0.047167
# ar.L1        0.949834
# ma.L1        0.419625
# sigma2       0.057023
# dtype: float64

# %%
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Statespace Model Results
# ==============================================================================
# Dep. Variable:                   TERM   No. Observations:                  801
# Model:               SARIMAX(1, 0, 1)   Log Likelihood                   8.974
# Date:                Fri, 24 Jan 2020   AIC                             -9.947
# Time:                        19:08:25   BIC                              8.796
# Sample:                    04-01-1953   HQIC                            -2.747
#                          - 12-01-2019
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0472      0.012      3.874      0.000       0.023       0.071
# ar.L1          0.9498      0.008    115.592      0.000       0.934       0.966
# ma.L1          0.4196      0.012     33.848      0.000       0.395       0.444
# sigma2         0.0570      0.001     42.504      0.000       0.054       0.060
# ===================================================================================
# Ljung-Box (Q):                       91.65   Jarque-Bera (JB):              3686.54
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.74   Skew:                             0.61
# Prob(H) (two-sided):                  0.01   Kurtosis:                        13.44
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """
