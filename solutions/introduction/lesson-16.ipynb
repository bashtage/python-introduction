# %% [markdown]
# # Boolean Selection
#
# This lesson covers:
#
# * Boolean selection
# * `where`
#
# Begin by loading the data in momentum.csv.

# %%
# Setup: Load the momentum data

import numpy as np
import pandas as pd

momentum = pd.read_csv("data/momentum.csv", index_col="date", parse_dates=True)

print(momentum.head())
# Out:
#             mom_01  mom_02  mom_03  mom_04  mom_05  mom_06  mom_07  mom_08  \
# date
# 2016-01-04    0.67   -0.03   -0.93   -1.11   -1.47   -1.66   -1.40   -2.08
# 2016-01-05   -0.36    0.20   -0.37    0.28    0.16    0.18   -0.22    0.25
# 2016-01-06   -4.97   -2.33   -2.60   -1.16   -1.70   -1.45   -1.15   -1.46
# 2016-01-07   -4.91   -1.91   -3.03   -1.87   -2.31   -2.30   -2.70   -2.31
# 2016-01-08   -0.40   -1.26   -0.98   -1.26   -1.13   -1.02   -0.96   -1.42
#
#             mom_09  mom_10
# date
# 2016-01-04   -1.71   -2.67
# 2016-01-05    0.29    0.13
# 2016-01-06   -1.14   -0.45
# 2016-01-07   -2.36   -2.66
# 2016-01-08   -0.94   -1.32

# %% [markdown]
# ## Problem: Selecting rows with boolean conditions
#
# Select the rows in `momentum` where all returns on a day are negative.

# %%
momentum.loc[(momentum < 0).all(axis=1)]
# Out:
#             mom_01  mom_02  mom_03  mom_04  mom_05  mom_06  mom_07  mom_08  \
# date
# 2016-01-06   -4.97   -2.33   -2.60   -1.16   -1.70   -1.45   -1.15   -1.46
# 2016-01-07   -4.91   -1.91   -3.03   -1.87   -2.31   -2.30   -2.70   -2.31
# 2016-01-08   -0.40   -1.26   -0.98   -1.26   -1.13   -1.02   -0.96   -1.42
# 2016-01-13   -4.88   -3.06   -2.70   -2.00   -2.34   -2.18   -2.44   -2.77
# 2016-01-15   -3.85   -2.87   -1.92   -2.09   -1.38   -2.46   -1.88   -2.23
# ...            ...     ...     ...     ...     ...     ...     ...     ...
# 2017-10-25   -0.77   -0.72   -0.33   -0.83   -0.28   -0.52   -0.23   -0.48
# 2017-10-30   -0.01   -0.72   -0.50   -0.91   -0.73   -0.27   -0.42   -0.04
# 2017-11-15   -0.20   -0.64   -0.65   -0.13   -0.37   -0.41   -0.75   -0.37
# 2017-12-14   -1.20   -0.99   -0.78   -0.26   -0.38   -0.41   -0.76   -0.32
# 2017-12-29   -0.42   -0.61   -0.48   -0.57   -0.45   -0.41   -0.52   -0.45
#
#             mom_09  mom_10
# date
# 2016-01-06   -1.14   -0.45
# 2016-01-07   -2.36   -2.66
# 2016-01-08   -0.94   -1.32
# 2016-01-13   -2.65   -3.71
# 2016-01-15   -2.28   -2.40
# ...            ...     ...
# 2017-10-25   -0.35   -1.52
# 2017-10-30   -0.41   -0.40
# 2017-11-15   -0.77   -0.59
# 2017-12-14   -0.60   -0.17
# 2017-12-29   -0.70   -0.94
#
# [74 rows x 10 columns]

# %% [markdown]
# ## Problem: Selecting rows
#
# Select the rows in `momentum` where 50% or more of the returns on a day are negative.

# %%
momentum.loc[(momentum < 0).mean(axis=1) >= 0.5]
# Out:
#             mom_01  mom_02  mom_03  mom_04  mom_05  mom_06  mom_07  mom_08  \
# date
# 2016-01-04    0.67   -0.03   -0.93   -1.11   -1.47   -1.66   -1.40   -2.08
# 2016-01-06   -4.97   -2.33   -2.60   -1.16   -1.70   -1.45   -1.15   -1.46
# 2016-01-07   -4.91   -1.91   -3.03   -1.87   -2.31   -2.30   -2.70   -2.31
# 2016-01-08   -0.40   -1.26   -0.98   -1.26   -1.13   -1.02   -0.96   -1.42
# 2016-01-11   -5.14   -0.81   -1.33   -0.72   -0.43    0.14    0.23    0.28
# ...            ...     ...     ...     ...     ...     ...     ...     ...
# 2017-12-19   -0.61    0.19   -0.41   -0.30   -0.17   -0.31   -0.41   -0.18
# 2017-12-22    0.24    0.13   -0.07   -0.01   -0.08   -0.10   -0.14   -0.16
# 2017-12-26    0.89    0.70    0.23   -0.03    0.10   -0.06   -0.14   -0.07
# 2017-12-27   -0.58   -0.55   -0.27   -0.19   -0.14    0.18    0.18    0.10
# 2017-12-29   -0.42   -0.61   -0.48   -0.57   -0.45   -0.41   -0.52   -0.45
#
#             mom_09  mom_10
# date
# 2016-01-04   -1.71   -2.67
# 2016-01-06   -1.14   -0.45
# 2016-01-07   -2.36   -2.66
# 2016-01-08   -0.94   -1.32
# 2016-01-11    0.29    0.33
# ...            ...     ...
# 2017-12-19   -0.15   -0.56
# 2017-12-22   -0.05   -0.01
# 2017-12-26    0.14   -0.65
# 2017-12-27    0.22    0.36
# 2017-12-29   -0.70   -0.94
#
# [243 rows x 10 columns]

# %% [markdown]
# ## Problem: Selecting columns
#
# Select the columns in `momentum` what have the smallest and second smallest average returns.

# %%
mean = momentum.mean()
mean = mean.sort_values()
mean
# Out:
# mom_09    0.042167
# mom_07    0.051789
# mom_10    0.060954
# mom_08    0.062604
# mom_05    0.069920
# mom_04    0.079145
# mom_06    0.080775
# mom_03    0.089801
# mom_02    0.094811
# mom_01    0.101909
# dtype: float64

# %%
momentum.loc[:, momentum.mean() < mean.iloc[2]]
# Out:
#             mom_07  mom_09
# date
# 2016-01-04   -1.40   -1.71
# 2016-01-05   -0.22    0.29
# 2016-01-06   -1.15   -1.14
# 2016-01-07   -2.70   -2.36
# 2016-01-08   -0.96   -0.94
# ...            ...     ...
# 2017-12-22   -0.14   -0.05
# 2017-12-26   -0.14    0.14
# 2017-12-27    0.18    0.22
# 2017-12-28    0.30    0.28
# 2017-12-29   -0.52   -0.70
#
# [503 rows x 2 columns]

# %%
momentum[mean.index[:2]]
# Out:
#             mom_09  mom_07
# date
# 2016-01-04   -1.71   -1.40
# 2016-01-05    0.29   -0.22
# 2016-01-06   -1.14   -1.15
# 2016-01-07   -2.36   -2.70
# 2016-01-08   -0.94   -0.96
# ...            ...     ...
# 2017-12-22   -0.05   -0.14
# 2017-12-26    0.14   -0.14
# 2017-12-27    0.22    0.18
# 2017-12-28    0.28    0.30
# 2017-12-29   -0.70   -0.52
#
# [503 rows x 2 columns]

# %% [markdown]
# ## Problem: Selecting rows and columns
#
# Select the returns for the column with the single most negative return
# on days where all of the returns are negative.

# %%
lowest = (momentum == momentum.min().min()).any()
lowest
# Out:
# mom_01     True
# mom_02    False
# mom_03    False
# mom_04    False
# mom_05    False
# mom_06    False
# mom_07    False
# mom_08    False
# mom_09    False
# mom_10    False
# dtype: bool

# %%
momentum.loc[(momentum < 0).all(axis=1), lowest]
# Out:
#             mom_01
# date
# 2016-01-06   -4.97
# 2016-01-07   -4.91
# 2016-01-08   -0.40
# 2016-01-13   -4.88
# 2016-01-15   -3.85
# ...            ...
# 2017-10-25   -0.77
# 2017-10-30   -0.01
# 2017-11-15   -0.20
# 2017-12-14   -1.20
# 2017-12-29   -0.42
#
# [74 rows x 1 columns]

# %% [markdown]
# ## Problem: Selecting Elements using Logical Statements
# For portfolio 1 and portfolio 10 compute the correlation when both
# returns are negative and when both are positive.

# %%
mom_01 = momentum.mom_01
mom_10 = momentum.mom_10

mom_01_neg = mom_01 < 0
mom_10_neg = mom_10 < 0
both_neg = mom_01_neg & mom_10_neg

momentum.loc[both_neg, ["mom_01", "mom_10"]].corr()
# Out:
#           mom_01    mom_10
# mom_01  1.000000  0.368096
# mom_10  0.368096  1.000000

# %%
sub = momentum[["mom_01", "mom_10"]]
sub.loc[(sub > 0).all(axis=1)].corr()
# Out:
#           mom_01    mom_10
# mom_01  1.000000  0.165254
# mom_10  0.165254  1.000000

# %%
# Setup: Reproducible random numbers

rs = np.random.RandomState(19991231)
x = rs.randint(1, 11, size=(10,3))
x
# Out:
# array([[ 5,  8, 10],
#        [10,  5,  9],
#        [ 6,  9, 10],
#        [ 8,  5,  9],
#        [ 2,  2,  4],
#        [ 5,  6,  7],
#        [10,  7,  2],
#        [ 4,  3,  5],
#        [ 6,  3,  9],
#        [10,  1,  9]])

# %% [markdown]
# ## Problem: Select the columns of x that means >= $E[x]$

# %%
x[:, x.mean(axis=0) >= 5.5]
# Out:
# array([[ 5, 10],
#        [10,  9],
#        [ 6, 10],
#        [ 8,  9],
#        [ 2,  4],
#        [ 5,  7],
#        [10,  2],
#        [ 4,  5],
#        [ 6,  9],
#        [10,  9]])

# %% [markdown]
# ## Problem: Select the rows of x that means >= $E[x]$

# %%
x[x.mean(axis=1) >= 5.5]
# Out:
# array([[ 5,  8, 10],
#        [10,  5,  9],
#        [ 6,  9, 10],
#        [ 8,  5,  9],
#        [ 5,  6,  7],
#        [10,  7,  2],
#        [ 6,  3,  9],
#        [10,  1,  9]])

# %% [markdown]
# ## Problem: Select the rows and column of x where both have means < $E[x]$

# %%
rows = x.mean(axis=1) >= 5.5
cols = x.mean(axis=0) >= 5.5

x[np.ix_(rows, cols)]
# Out:
# array([[ 5, 10],
#        [10,  9],
#        [ 6, 10],
#        [ 8,  9],
#        [ 5,  7],
#        [10,  2],
#        [ 6,  9],
#        [10,  9]])

# %% [markdown]
# ## Problem: Using `where`
# Use `where` to select the index of the elements in portfolio 5 that are
# negative. Next, use the `where` command in its two output form to determine
# which elements of the portfolio return matrix are less than -2%.

# %%
mom_05 = momentum.mom_05
np.where(mom_05 < 0)
# Out:
# (array([  0,   2,   3,   4,   5,   7,   9,  10,  11,  14,  16,  19,  20,
#          23,  24,  25,  26,  27,  31,  32,  34,  38,  44,  48,  49,  54,
#          55,  56,  57,  60,  62,  63,  65,  70,  71,  75,  77,  79,  80,
#          81,  83,  84,  87,  89,  90,  91,  93,  97, 100, 105, 109, 110,
#         111, 112, 113, 114, 117, 118, 120, 121, 126, 135, 136, 138, 140,
#         142, 143, 144, 145, 146, 148, 150, 152, 154, 156, 160, 162, 164,
#         167, 168, 170, 173, 175, 176, 178, 180, 183, 184, 187, 189, 190,
#         193, 195, 197, 199, 202, 205, 206, 207, 209, 210, 211, 212, 213,
#         217, 223, 228, 230, 231, 232, 238, 240, 242, 245, 246, 247, 249,
#         251, 254, 256, 261, 263, 265, 268, 270, 271, 275, 276, 277, 283,
#         287, 290, 292, 293, 294, 295, 300, 302, 303, 304, 305, 307, 308,
#         309, 314, 316, 318, 320, 321, 322, 324, 325, 327, 331, 332, 335,
#         338, 339, 341, 342, 344, 345, 353, 357, 358, 360, 365, 368, 373,
#         375, 379, 381, 382, 391, 393, 395, 398, 399, 400, 402, 403, 404,
#         407, 409, 410, 413, 414, 416, 421, 424, 428, 430, 433, 437, 444,
#         445, 448, 451, 452, 455, 457, 460, 463, 465, 467, 468, 471, 472,
#         474, 477, 479, 485, 486, 491, 492, 495, 498, 500, 502], dtype=int64),)

# %%
loc = np.where(mom_05 < 0)
mom_05.iloc[loc]
# Out:
# date
# 2016-01-04   -1.47
# 2016-01-06   -1.70
# 2016-01-07   -2.31
# 2016-01-08   -1.13
# 2016-01-11   -0.43
#               ...
# 2017-12-14   -0.38
# 2017-12-19   -0.17
# 2017-12-22   -0.08
# 2017-12-27   -0.14
# 2017-12-29   -0.45
# Name: mom_05, Length: 219, dtype: float64

# %%
loc = np.where(momentum < 0)
# Two arrays, one for rows and one for columns where momentum < 0
print(loc)
# Out:
# (array([  0,   0,   0, ..., 502, 502, 502], dtype=int64), array([1, 2, 3, ..., 7, 8, 9], dtype=int64))

# %% [markdown]
# ## Exercises
#
# ### Exercise: Select the Most Volatile Portfolio
#
# Select the column in momentum that has the highest standard deviation.

# %%
max_std = momentum.std().max()
momentum.loc[:, momentum.std() == max_std].head()
# Out:
#             mom_01
# date
# 2016-01-04    0.67
# 2016-01-05   -0.36
# 2016-01-06   -4.97
# 2016-01-07   -4.91
# 2016-01-08   -0.40

# %% [markdown]
# ### Exercise: Select the High Kurtosis Portfolios
#
# Select the columns that have kurtoses above the median kurtosis.

# %%
kurtosis = momentum.kurt()
sel = kurtosis > kurtosis.median()
momentum.loc[:, sel].head()
# Out:
#             mom_01  mom_03  mom_04  mom_05  mom_06
# date
# 2016-01-04    0.67   -0.93   -1.11   -1.47   -1.66
# 2016-01-05   -0.36   -0.37    0.28    0.16    0.18
# 2016-01-06   -4.97   -2.60   -1.16   -1.70   -1.45
# 2016-01-07   -4.91   -3.03   -1.87   -2.31   -2.30
# 2016-01-08   -0.40   -0.98   -1.26   -1.13   -1.02

# %% [markdown]
# ### Exercise: Select
#
# Select the rows where all of the returns in the row are less than the 25%
# quantile for their portfolio.
#
# **Note**: Comparisons between `DataFrame`s and `Series` works like mathematical
# operations (`+`, `-`, etc.).

# %%
quantiles = momentum.quantile(0.25)
less_than_quantile = momentum < quantiles
less_than_quantile.head()
# Out:
#             mom_01  mom_02  mom_03  mom_04  mom_05  mom_06  mom_07  mom_08  \
# date
# 2016-01-04   False   False    True    True    True    True    True    True
# 2016-01-05   False   False    True   False   False   False   False   False
# 2016-01-06    True    True    True    True    True    True    True    True
# 2016-01-07    True    True    True    True    True    True    True    True
# 2016-01-08   False    True    True    True    True    True    True    True
#
#             mom_09  mom_10
# date
# 2016-01-04    True    True
# 2016-01-05   False   False
# 2016-01-06    True    True
# 2016-01-07    True    True
# 2016-01-08    True    True

# %%
sel = less_than_quantile.all(axis=1)
momentum.loc[sel]
# Out:
#             mom_01  mom_02  mom_03  mom_04  mom_05  mom_06  mom_07  mom_08  \
# date
# 2016-01-06   -4.97   -2.33   -2.60   -1.16   -1.70   -1.45   -1.15   -1.46
# 2016-01-07   -4.91   -1.91   -3.03   -1.87   -2.31   -2.30   -2.70   -2.31
# 2016-01-13   -4.88   -3.06   -2.70   -2.00   -2.34   -2.18   -2.44   -2.77
# 2016-01-15   -3.85   -2.87   -1.92   -2.09   -1.38   -2.46   -1.88   -2.23
# 2016-01-25   -5.97   -3.67   -2.34   -2.16   -1.85   -1.71   -1.33   -1.44
# 2016-01-27   -0.68   -0.87   -0.47   -0.61   -1.90   -0.97   -0.53   -0.63
# 2016-02-02   -4.57   -3.03   -2.67   -2.83   -2.09   -1.25   -1.86   -1.98
# 2016-02-05   -2.49   -2.40   -1.52   -1.77   -1.77   -0.93   -1.47   -1.62
# 2016-02-08   -5.37   -3.92   -1.59   -1.08   -0.52   -1.26   -1.85   -1.00
# 2016-02-23   -4.09   -2.74   -1.65   -1.52   -1.70   -1.40   -1.12   -0.92
# 2016-04-05   -0.86   -1.18   -1.16   -0.94   -1.09   -0.84   -1.49   -1.01
# 2016-05-03   -4.13   -2.84   -1.73   -1.81   -0.91   -0.96   -1.06   -0.60
# 2016-05-13   -0.81   -0.81   -0.48   -1.15   -1.07   -0.94   -0.62   -0.81
# 2016-06-10   -3.72   -2.63   -1.91   -1.98   -1.59   -0.95   -0.80   -0.72
# 2016-06-24   -4.91   -5.53   -5.36   -4.58   -4.96   -4.92   -3.86   -3.05
# 2016-06-27   -5.53   -5.01   -3.77   -3.26   -2.76   -2.91   -1.97   -1.20
# 2016-08-24   -2.11   -1.49   -0.51   -0.73   -0.28   -0.56   -0.40   -0.40
# 2016-09-09   -3.09   -2.88   -1.88   -2.28   -2.05   -2.39   -2.47   -2.54
# 2016-09-13   -2.09   -1.57   -2.02   -0.60   -1.53   -1.54   -1.54   -1.57
# 2016-09-26   -0.95   -1.10   -1.28   -1.08   -0.97   -0.87   -0.75   -0.77
# 2016-09-29   -1.49   -1.43   -1.38   -1.19   -0.93   -0.77   -0.74   -1.05
# 2016-10-11   -2.20   -1.66   -1.29   -0.97   -1.31   -1.10   -1.37   -1.27
# 2016-11-02   -1.71   -0.97   -0.57   -0.73   -0.55   -0.89   -0.39   -0.60
# 2016-12-14   -1.01   -0.81   -0.75   -0.74   -0.96   -0.76   -0.58   -0.86
# 2016-12-28   -1.01   -0.96   -0.78   -0.80   -0.65   -0.82   -0.76   -1.01
# 2017-03-21   -1.68   -0.69   -0.58   -0.89   -1.32   -1.14   -1.66   -2.21
# 2017-05-17   -1.83   -1.02   -1.12   -1.42   -1.21   -1.74   -2.49   -2.55
# 2017-07-06   -2.32   -1.61   -1.16   -0.87   -0.92   -0.71   -0.84   -0.63
# 2017-08-10   -2.46   -1.00   -1.04   -0.99   -0.93   -1.09   -1.46   -1.59
# 2017-08-17   -1.21   -1.18   -1.38   -1.25   -1.73   -1.38   -1.62   -1.73
#
#             mom_09  mom_10
# date
# 2016-01-06   -1.14   -0.45
# 2016-01-07   -2.36   -2.66
# 2016-01-13   -2.65   -3.71
# 2016-01-15   -2.28   -2.40
# 2016-01-25   -1.62   -1.12
# 2016-01-27   -1.16   -2.02
# 2016-02-02   -1.91   -1.70
# 2016-02-05   -2.04   -3.91
# 2016-02-08   -1.84   -2.01
# 2016-02-23   -0.42   -1.01
# 2016-04-05   -0.77   -0.77
# 2016-05-03   -0.72   -0.81
# 2016-05-13   -0.86   -0.45
# 2016-06-10   -0.39   -0.79
# 2016-06-24   -2.80   -2.25
# 2016-06-27   -1.36   -0.92
# 2016-08-24   -0.42   -0.89
# 2016-09-09   -2.71   -3.06
# 2016-09-13   -1.39   -1.67
# 2016-09-26   -0.58   -0.56
# 2016-09-29   -0.67   -0.82
# 2016-10-11   -1.55   -1.62
# 2016-11-02   -1.02   -1.09
# 2016-12-14   -1.35   -0.73
# 2016-12-28   -1.26   -1.80
# 2017-03-21   -2.91   -4.03
# 2017-05-17   -3.08   -4.30
# 2017-07-06   -0.79   -0.85
# 2017-08-10   -2.36   -2.58
# 2017-08-17   -1.84   -2.19
