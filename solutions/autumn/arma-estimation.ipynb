# %% [markdown]
# ## ARMA Modeling: Estimation
#
# **Functions**
#
# `tsa.SARIMAX`

# %%
import pandas as pd

data = pd.read_hdf("data/term-premium.h5","term_premium")
term = data.TERM

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
plt.rc("figure", figsize=(16,6))
sns.set_style("darkgrid")

term.plot.line()

# %% [markdown]
# ### Exercise 41
# Estimate an AR(1) on the term premium, and compute standard errors for the parameters.

# %%
import statsmodels.tsa.api as tsa

mod = tsa.SARIMAX(term, order=(1,0,0), trend='c')
res = mod.fit()
res.params
# Out:
# intercept    0.026495
# ar.L1        0.971059
# sigma2       0.065326
# dtype: float64

# %%
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Statespace Model Results
# ==============================================================================
# Dep. Variable:                   TERM   No. Observations:                  799
# Model:               SARIMAX(1, 0, 0)   Log Likelihood                 -45.201
# Date:                Thu, 21 Nov 2019   AIC                             96.403
# Time:                        13:21:32   BIC                            110.453
# Sample:                    04-01-1953   HQIC                           101.800
#                          - 10-01-2019
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0265      0.009      2.858      0.004       0.008       0.045
# ar.L1          0.9711      0.006    152.121      0.000       0.959       0.984
# sigma2         0.0653      0.001     57.164      0.000       0.063       0.068
# ===================================================================================
# Ljung-Box (Q):                      174.02   Jarque-Bera (JB):              9653.97
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.78   Skew:                             0.92
# Prob(H) (two-sided):                  0.04   Kurtosis:                        19.93
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ### Exercise 42
# Estimate an MA(5) on the term premium, and compute standard errors for the parameters.

# %%
mod = tsa.SARIMAX(term, order=(0,0,5), trend='c')
res = mod.fit()
res.params
# Out:
# c:\git\statsmodels\statsmodels\tsa\statespace\sarimax.py:973: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# intercept    0.965401
# ma.L1        1.518097
# ma.L2        1.433216
# ma.L3        1.192445
# ma.L4        0.747661
# ma.L5        0.293859
# sigma2       0.084323
# dtype: float64

# %%
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Statespace Model Results
# ==============================================================================
# Dep. Variable:                   TERM   No. Observations:                  799
# Model:               SARIMAX(0, 0, 5)   Log Likelihood                -147.119
# Date:                Thu, 21 Nov 2019   AIC                            308.238
# Time:                        13:21:33   BIC                            341.022
# Sample:                    04-01-1953   HQIC                           320.833
#                          - 10-01-2019
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.9654      0.066     14.603      0.000       0.836       1.095
# ma.L1          1.5181      0.016     93.469      0.000       1.486       1.550
# ma.L2          1.4332      0.030     48.348      0.000       1.375       1.491
# ma.L3          1.1924      0.036     33.098      0.000       1.122       1.263
# ma.L4          0.7477      0.036     20.985      0.000       0.678       0.817
# ma.L5          0.2939      0.024     12.028      0.000       0.246       0.342
# sigma2         0.0843      0.003     31.150      0.000       0.079       0.090
# ===================================================================================
# Ljung-Box (Q):                      948.51   Jarque-Bera (JB):               652.81
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.07   Skew:                            -0.33
# Prob(H) (two-sided):                  0.60   Kurtosis:                         7.38
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ### Exercise 43
# Estimate an ARMA(1,1) on the term premium, and compute standard errors for the parameters.

# %%
mod = tsa.SARIMAX(term, order=(1,0,1), trend='c')
res = mod.fit()
res.params
# Out:
# intercept    0.046979
# ar.L1        0.949912
# ma.L1        0.419527
# sigma2       0.057162
# dtype: float64

# %%
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Statespace Model Results
# ==============================================================================
# Dep. Variable:                   TERM   No. Observations:                  799
# Model:               SARIMAX(1, 0, 1)   Log Likelihood                   7.975
# Date:                Thu, 21 Nov 2019   AIC                             -7.950
# Time:                        13:21:34   BIC                             10.783
# Sample:                    04-01-1953   HQIC                            -0.753
#                          - 10-01-2019
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0470      0.012      3.849      0.000       0.023       0.071
# ar.L1          0.9499      0.008    115.322      0.000       0.934       0.966
# ma.L1          0.4195      0.012     33.760      0.000       0.395       0.444
# sigma2         0.0572      0.001     42.394      0.000       0.055       0.060
# ===================================================================================
# Ljung-Box (Q):                       91.44   Jarque-Bera (JB):              3658.48
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.74   Skew:                             0.61
# Prob(H) (two-sided):                  0.02   Kurtosis:                        13.41
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """
