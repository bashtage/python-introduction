# %% [markdown]
# ## ARMA Estimation
#
# **Functions**
#
# `tsa.SARIMAX`

# %%
import pandas as pd

data = pd.read_hdf("data/term-premium.h5","term_premium")
term = data.TERM

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
plt.rc("figure", figsize=(12,8))
sns.set_style("darkgrid")

term.plot.line()

# %% [markdown]
# ### Exercise 41
# Estimate an AR(1) on the term premium, and compute standard errors for the parameters.

# %%
import statsmodels.tsa.api as tsa

mod = tsa.SARIMAX(term, order=(1,0,0), trend='c')
res = mod.fit()
res.params
# Out:
# intercept    0.026110
# ar.L1        0.971249
# sigma2       0.065371
# dtype: float64

# %%
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Statespace Model Results
# ==============================================================================
# Dep. Variable:                   TERM   No. Observations:                  798
# Model:               SARIMAX(1, 0, 0)   Log Likelihood                 -45.423
# Date:                Thu, 24 Oct 2019   AIC                             96.846
# Time:                        17:22:25   BIC                            110.893
# Sample:                    04-01-1953   HQIC                           102.243
#                          - 09-01-2019
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0261      0.009      2.812      0.005       0.008       0.044
# ar.L1          0.9712      0.006    152.030      0.000       0.959       0.984
# sigma2         0.0654      0.001     57.117      0.000       0.063       0.068
# ===================================================================================
# Ljung-Box (Q):                      174.33   Jarque-Bera (JB):              9652.71
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.77   Skew:                             0.93
# Prob(H) (two-sided):                  0.04   Kurtosis:                        19.94
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ### Exercise 42
# Estimate an MA(5) on the term premium, and compute standard errors for the parameters.

# %%
mod = tsa.SARIMAX(term, order=(0,0,5), trend='c')
res = mod.fit()
res.params
# Out:
# c:\git\statsmodels\statsmodels\tsa\statespace\sarimax.py:973: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# intercept    0.965747
# ma.L1        1.518091
# ma.L2        1.432856
# ma.L3        1.192235
# ma.L4        0.747857
# ma.L5        0.293926
# sigma2       0.084426
# dtype: float64

# %%
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Statespace Model Results
# ==============================================================================
# Dep. Variable:                   TERM   No. Observations:                  798
# Model:               SARIMAX(0, 0, 5)   Log Likelihood                -147.424
# Date:                Thu, 24 Oct 2019   AIC                            308.849
# Time:                        17:22:26   BIC                            341.624
# Sample:                    04-01-1953   HQIC                           321.441
#                          - 09-01-2019
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.9657      0.066     14.589      0.000       0.836       1.095
# ma.L1          1.5181      0.016     93.365      0.000       1.486       1.550
# ma.L2          1.4329      0.030     48.271      0.000       1.375       1.491
# ma.L3          1.1922      0.036     33.051      0.000       1.122       1.263
# ma.L4          0.7479      0.036     20.962      0.000       0.678       0.818
# ma.L5          0.2939      0.024     12.015      0.000       0.246       0.342
# sigma2         0.0844      0.003     31.106      0.000       0.079       0.090
# ===================================================================================
# Ljung-Box (Q):                      946.94   Jarque-Bera (JB):               649.54
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.07   Skew:                            -0.33
# Prob(H) (two-sided):                  0.60   Kurtosis:                         7.37
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ### Exercise 43
# Estimate an ARMA(1,1) on the term premium, and compute standard errors for the parameters.

# %%
mod = tsa.SARIMAX(term, order=(1,0,1), trend='c')
res = mod.fit()
res.params
# Out:
# intercept    0.046609
# ar.L1        0.950109
# ma.L1        0.418882
# sigma2       0.057219
# dtype: float64

# %%
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Statespace Model Results
# ==============================================================================
# Dep. Variable:                   TERM   No. Observations:                  798
# Model:               SARIMAX(1, 0, 1)   Log Likelihood                   7.561
# Date:                Thu, 24 Oct 2019   AIC                             -7.122
# Time:                        17:22:26   BIC                             11.606
# Sample:                    04-01-1953   HQIC                             0.073
#                          - 09-01-2019
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0466      0.012      3.815      0.000       0.023       0.071
# ar.L1          0.9501      0.008    115.262      0.000       0.934       0.966
# ma.L1          0.4189      0.012     33.672      0.000       0.394       0.443
# sigma2         0.0572      0.001     42.348      0.000       0.055       0.060
# ===================================================================================
# Ljung-Box (Q):                       91.54   Jarque-Bera (JB):              3658.36
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.74   Skew:                             0.62
# Prob(H) (two-sided):                  0.02   Kurtosis:                        13.42
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """
