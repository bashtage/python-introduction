# %% [markdown]
# ## ARMA Modeling: Estimation
#
# **Functions**
#
# `tsa.SARIMAX`

# %%
import pandas as pd

data = pd.read_hdf("data/term-premium.h5","term_premium")
term = data.TERM

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
plt.rc("figure", figsize=(16,6))
sns.set_style("darkgrid")

term.plot.line()

# %% [markdown]
# ### Exercise 65
# Estimate an AR(1) on the term premium, and compute standard errors for the parameters.

# %%
import statsmodels.tsa.api as tsa

mod = tsa.SARIMAX(term, order=(1,0,0), trend='c')
res = mod.fit()
res.params
# Out:
# intercept    0.026635
# ar.L1        0.970991
# sigma2       0.065114
# dtype: float64

# %%
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   TERM   No. Observations:                  802
# Model:               SARIMAX(1, 0, 0)   Log Likelihood                 -44.059
# Date:                Wed, 26 Feb 2020   AIC                             94.119
# Time:                        15:37:00   BIC                            108.180
# Sample:                    04-01-1953   HQIC                            99.520
#                          - 01-01-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0266      0.009      2.883      0.004       0.009       0.045
# ar.L1          0.9710      0.006    152.606      0.000       0.959       0.983
# sigma2         0.0651      0.001     57.359      0.000       0.063       0.067
# ===================================================================================
# Ljung-Box (Q):                      174.66   Jarque-Bera (JB):              9747.97
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.78   Skew:                             0.92
# Prob(H) (two-sided):                  0.04   Kurtosis:                        19.98
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ### Exercise 66
# Estimate an MA(5) on the term premium, and compute standard errors for the parameters.

# %%
mod = tsa.SARIMAX(term, order=(0,0,5), trend='c')
res = mod.fit()
res.params
# Out:
# /mnt/c/git/statsmodels/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# intercept    0.961837
# ma.L1        1.519003
# ma.L2        1.434940
# ma.L3        1.193187
# ma.L4        0.746879
# ma.L5        0.293389
# sigma2       0.084112
# dtype: float64

# %%
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   TERM   No. Observations:                  802
# Model:               SARIMAX(0, 0, 5)   Log Likelihood                -146.659
# Date:                Wed, 26 Feb 2020   AIC                            307.318
# Time:                        15:37:01   BIC                            340.127
# Sample:                    04-01-1953   HQIC                           319.920
#                          - 01-01-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.9618      0.066     14.601      0.000       0.833       1.091
# ma.L1          1.5190      0.016     93.717      0.000       1.487       1.551
# ma.L2          1.4349      0.030     48.495      0.000       1.377       1.493
# ma.L3          1.1932      0.036     33.170      0.000       1.123       1.264
# ma.L4          0.7469      0.036     21.008      0.000       0.677       0.817
# ma.L5          0.2934      0.024     12.044      0.000       0.246       0.341
# sigma2         0.0841      0.003     31.237      0.000       0.079       0.089
# ===================================================================================
# Ljung-Box (Q):                      955.31   Jarque-Bera (JB):               656.00
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.07   Skew:                            -0.32
# Prob(H) (two-sided):                  0.57   Kurtosis:                         7.38
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ### Exercise 67
# Estimate an ARMA(1,1) on the term premium, and compute standard errors for the parameters.

# %%
mod = tsa.SARIMAX(term, order=(1,0,1), trend='c')
res = mod.fit()
res.params
# Out:
# intercept    0.046863
# ar.L1        0.949947
# ma.L1        0.419563
# sigma2       0.056969
# dtype: float64

# %%
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   TERM   No. Observations:                  802
# Model:               SARIMAX(1, 0, 1)   Log Likelihood                   9.368
# Date:                Wed, 26 Feb 2020   AIC                            -10.735
# Time:                        15:37:01   BIC                              8.013
# Sample:                    04-01-1953   HQIC                            -3.534
#                          - 01-01-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0469      0.012      3.853      0.000       0.023       0.071
# ar.L1          0.9499      0.008    115.712      0.000       0.934       0.966
# ma.L1          0.4196      0.012     33.880      0.000       0.395       0.444
# sigma2         0.0570      0.001     42.543      0.000       0.054       0.060
# ===================================================================================
# Ljung-Box (Q):                       91.76   Jarque-Bera (JB):              3701.59
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.74   Skew:                             0.62
# Prob(H) (two-sided):                  0.01   Kurtosis:                        13.45
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """
